# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
# 1. concept of Models(LLM Wrappers)
# text completion model
from langchain.llms import OpenAI
llm = OpenAI(model_name = "text-davinci-003")
llm("explain large language models in one sentence")
# Out:
# '\n\nLarge language models are neural networks trained on a large amount of text data to predict the next word in a sequence.'

# %%
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage,
)
from langchain.chat_models import ChatOpenAI

# %%
# chat model
chat = ChatOpenAI(model_name="gpt-4", temperature=0.3)
messages = [
    SystemMessage(content="You are an expert data scientist"),
    HumanMessage(content="Write a Python script that trains a neural network on simulated data ")
]
response=chat(messages)
# chat model

# %%
print(response.content, end='\n')
# Out:
# Sure, here is a simple example of a Python script that trains a neural network using the Keras library. In this example, we will use a very basic dataset for simplicity - the Boston Housing dataset, which is a built-in dataset in the Keras library. This dataset contains information collected by the U.S Census Service concerning housing in the area of Boston Mass.
#
# ```python
# # Import necessary libraries
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.datasets import boston_housing
#
# # Load dataset
# (x_train, y_train), (x_test, y_test) = boston_housing.load_data()
#
# # Define model
# model = Sequential()
# model.add(Dense(64, activation='relu', input_shape=(x_train.shape[1],)))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(1))
#
# # Compile model
# model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
#
# # Train model
# model.fit(x_train, y_train, epochs=10, batch_size=1, verbose=1)
#
# # Evaluate model
# test_mse_score, test_mae_score = model.evaluate(x_test, y_test)
#
# print("Test MSE Score:", test_mse_score)
# print("Test MAE Score:", test_mae_score)
# ```
#
# This script first loads the Boston Housing dataset, then defines a simple neural network with two hidden layers. The model is compiled with the RMSprop optimizer and Mean Squared Error (MSE) as the loss function. Mean Absolute Error (MAE) is used as a metric. The model is then trained on the training data for 10 epochs. Finally, the model is evaluated on the test data and the MSE and MAE scores are printed.
#
# Please note that this is a very basic example and in a real-world scenario, you would need to preprocess your data, tune your model's hyperparameters, possibly use a more complex model, etc.

# %%
# 2. concept of prompts
from langchain import PromptTemplate

template = """
You are an expert data scientist with an expertise in building deep learning models.
Explain the concept of {concept} in couple of lines
"""

prompt = PromptTemplate(
    input_variables=["concept"],
    template=template,
)

# %%
prompt
# Out:
# PromptTemplate(input_variables=['concept'], output_parser=None, partial_variables={}, template='\nYou are an expert data scientist with an expertise in building deep learning models.\nExplain the concept of {concept} in couple of lines\n', template_format='f-string', validate_template=True)

# %%
llm(prompt.format(concept="autoencoder"))
# Out:
# '\nAn autoencoder is a type of artificial neural network used to learn efficient representations of input data, typically for the purpose of dimensionality reduction. It works by training a network to encode input data into a lower-dimensional representation (the "encoding"), then decoding this representation back to the original data.'

# %%
# 3. concept of chains
from langchain.chains import LLMChain
chain = LLMChain(llm=llm, prompt=prompt)

# Run the chain only specifying the input variable
print(chain.run("autoencoder"))
# Out:
# Autoencoders are a type of neural network that is used to learn an efficient representation of the input data, usually for the purpose of dimensionality reduction, feature extraction, or anomaly detection. It works by compressing the input data into a lower-dimensional representation, and then reconstructing the original input from that lower-dimensional representation.

# %%
second_prompt = PromptTemplate(
    input_variables = ["ml_concept"],
    template = "Turn the concept description of {ml_concept} and explain it to me like I'm five in 500 words",
)

chain_two = LLMChain(llm=llm, prompt=second_prompt)

# %%
from langchain.chains import SimpleSequentialChain
overall_chain = SimpleSequentialChain(chains=[chain, chain_two], verbose=True)

# Run the chain specifying only the input variable for the first chain.
explanation = overall_chain.run("autoencoder")
print(explanation)
# Out:
# > Entering new SimpleSequentialChain chain...
#
# Autoencoders are a type of artificial neural network used for unsupervised learning. They are trained to learn how to represent data in a compressed, lower-dimensional latent space, and can be used for dimensionality reduction, denoising, or generative modeling.
#
#
# Autoencoders are a type of computer program that helps computers learn how to do something without being told what to do. It's kind of like teaching a puppy how to sit without saying "sit." Autoencoders are a type of artificial neural network, which is a type of computer program that is made up of a bunch of connected parts that act like neurons in our brains.
#
# Autoencoders are used for something called unsupervised learning. This means that the computer is given a bunch of information, but it doesn't know anything about the information. The autoencoder then looks at the information and tries to figure out what it means. For example, it might look at a bunch of pictures of people and try to figure out what makes them different.
#
# The autoencoder is trained to learn how to represent the data in a simpler, lower-dimensional way. This is called latent space. Basically, it takes all the information from the data and simplifies it into something that is easier to understand and use. This helps the computer make better decisions and do better tasks.
#
# Autoencoders can be used for many different things. One of the main uses is for dimensionality reduction. This means that it
#
# > Finished chain.
#
#
# Autoencoders are a type of computer program that helps computers learn how to do something without being told what to do. It's kind of like teaching a puppy how to sit without saying "sit." Autoencoders are a type of artificial neural network, which is a type of computer program that is made up of a bunch of connected parts that act like neurons in our brains.
#
# Autoencoders are used for something called unsupervised learning. This means that the computer is given a bunch of information, but it doesn't know anything about the information. The autoencoder then looks at the information and tries to figure out what it means. For example, it might look at a bunch of pictures of people and try to figure out what makes them different.
#
# The autoencoder is trained to learn how to represent the data in a simpler, lower-dimensional way. This is called latent space. Basically, it takes all the information from the data and simplifies it into something that is easier to understand and use. This helps the computer make better decisions and do better tasks.
#
# Autoencoders can be used for many different things. One of the main uses is for dimensionality reduction. This means that it

# %%
# 4. concept of embeddings and vectorstores
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap = 0,
)

texts = text_splitter.create_documents([explanation])

# %%
texts
# Out:
# [Document(page_content='Autoencoders are a type of computer program that helps computers learn how to do something without', metadata={}),
#  Document(page_content='being told what to do. It\'s kind of like teaching a puppy how to sit without saying "sit."', metadata={}),
#  Document(page_content='Autoencoders are a type of artificial neural network, which is a type of computer program that is', metadata={}),
#  Document(page_content='made up of a bunch of connected parts that act like neurons in our brains.', metadata={}),
#  Document(page_content='Autoencoders are used for something called unsupervised learning. This means that the computer is', metadata={}),
#  Document(page_content="given a bunch of information, but it doesn't know anything about the information. The autoencoder", metadata={}),
#  Document(page_content='then looks at the information and tries to figure out what it means. For example, it might look at a', metadata={}),
#  Document(page_content='bunch of pictures of people and try to figure out what makes them different.', metadata={}),
#  Document(page_content='The autoencoder is trained to learn how to represent the data in a simpler, lower-dimensional way.', metadata={}),
#  Document(page_content='This is called latent space. Basically, it takes all the information from the data and simplifies it', metadata={}),
#  Document(page_content='into something that is easier to understand and use. This helps the computer make better decisions', metadata={}),
#  Document(page_content='and do better tasks.', metadata={}),
#  Document(page_content='Autoencoders can be used for many different things. One of the main uses is for dimensionality', metadata={}),
#  Document(page_content='reduction. This means that it', metadata={})]

# %%
texts[0].page_content
# Out:
# 'Autoencoders are a type of computer program that helps computers learn how to do something without'

# %%
from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(
#  -0.0038266939240175673,
#  -0.008678942122351685,
#  -0.009270804146977153,
#  0.07388070340548411,
#  -0.01571495669173967,
#  -0.03128704849831278,
#  -0.015439434216982984,
#  0.014633277658575436,
#  0.028552238341898767,
#  0.029021647278542784,
#  0.0039670058211367844,
#  -0.02451125011692977,
#  0.02918491930428151,
#  0.019092651380822508,
#  0.00883200964648174,
#  0.030491097372836493,
#  -0.0019707472835575543,
#  -0.03163400341565275,
#  0.06992135305602964,
#  -0.00794421614388224,
#  -0.016061909746434466,
#  0.00020090143101092229,
#  -0.04816532209873123,
#  -0.009000384388686094,
#  0.03989966275719199,
#  -0.010393300255253483,
#  -0.05290021457044464,
#  0.02009269440111738,
#  0.023449980086982875,
#  0.04175688391261517,
#  -0.05371657842442862,
#  -0.011378036057474056,
#  0.03708321658790861,
#  0.005627791019085006,
#  0.016663976272668603,
#  -0.056043208516495815,
#  -0.047267322231877885,
#  0.009883075174819964,
#  -0.11690294924286476,
#  0.07139080128767818,
#  -0.04885922820812082,
#  0.03259322842951294,
#  0.021021304978828974,
#  0.0035231095354983292,
#  -0.04114461381609495,
#  -0.037715893825001,
#  0.014296528174166725,
#  -0.016674181705599863,
#  -0.002882776128231675,
#  0.01648029524371254,
#  -0.04963477033037976,
#  -0.033776950616118705,
#  -0.009036099678655147,
#  -0.01862324430682367,
#  -0.017766064309050183,
#  -0.02449084111371243,
#  -0.05881883667934451,
#  -0.03302181563443192,
#  0.015500661226635005,
#  -0.0033394282737116156,
#  0.009689188712932638,
#  ...]

# %%
import os
import pinecone
from langchain.vectorstores import Pinecone

#initialize pinecone
pinecone.init(
    api_key=os.getenv('PINECONE_API_KEY'),
    environment=os.getenv('PINECONE_ENV')
)

# %%
index_name = "langchain"
search = Pinecone.from_documents(texts, embeddings, index_name=index_name)

# %%
query = "what is magical about an autoencoder?"
result = search.similarity_search(query)

# %%
result
# Out:
# [Document(page_content="given a bunch of information, but it doesn't know anything about the information. The autoencoder", metadata={}),
#  Document(page_content='The autoencoder is trained to learn how to represent the data in a simpler, lower-dimensional way.', metadata={}),
#  Document(page_content='Autoencoders are a type of artificial neural network, which is a type of computer program that is', metadata={}),
#  Document(page_content='Autoencoders are a type of computer program that helps computers learn how to do something without', metadata={})]

# %%
# 5. concept of agent

from langchain.agents.agent_toolkits import create_python_agent
from langchain.tools.python.tool import PythonREPLTool
from langchain.python import PythonREPL
from langchain.llms.openai import OpenAI

# %%
agent_executor = create_python_agent(
    llm=OpenAI(temperature=0, max_tokens=1000),
    tool=PythonREPLTool(),
    verbose=True
)

# %%
agent_executor.run("Find the roots (zero) if the quadratic function 3 * x**2 + 2*x -1")
# Out:
# > Entering new AgentExecutor chain...
#  I need to solve a quadratic equation
# Action: Python REPL
# Action Input: import numpy as np
# Observation:
# Thought: I can use the numpy function to solve the equation
# Action: Python REPL
# Action Input: np.roots([3,2,-1])
# Observation:
# Thought: I now know the final answer
# Final Answer: (-1.0, 0.3333333333333333)
#
# > Finished chain.
# '(-1.0, 0.3333333333333333)'
